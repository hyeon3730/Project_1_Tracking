# %%
import os
import cv2
import matplotlib.pyplot as plt
import glob

# %%
cur_path =  os.getcwd() #현재 작업 경로 가져오는 함수
print(cur_path, type(cur_path))
# Out:
# /home/hyeon/MAIN/folio/tracking/code <class 'str'>

# %%
path = '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/*'
glob.glob(path)
# Out:
# ['/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000536.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000048.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000832.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000595.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000275.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000282.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000351.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000269.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000550.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000377.jpg',
#  '/home/hyeon/MAIN/folio/tracking/DATA/MOT17/train/MOT17-05-DPM/img1/000393.jpg',
# ...

# %%
# !tree -d /home/hyeon/MAIN/folio/tracking/DATA/MOT17
# Out:
# /home/hyeon/MAIN/folio/tracking/DATA/MOT17
# ├── test
# │   ├── MOT17-01-DPM
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-01-FRCNN
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-01-SDP
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-03-DPM
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-03-FRCNN
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-03-SDP
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-06-DPM
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-06-FRCNN
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-06-SDP
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-07-DPM
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-07-FRCNN
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-07-SDP
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-08-DPM
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-08-FRCNN
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-08-SDP
# │   │   ├── det
# │   │   └── img1
# │   ├── MOT17-12-DPM
# ...

# %%
# 이미지 파일 경로 설정
image_path = '/home/hyeon/MAIN/\
folio/tracking/DATA/MOT17/\
train/MOT17-05-DPM/img1/000536.jpg'

# 이미지 불러오기
image = cv2.imread(image_path) #이미지 불러오기
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) #색변환 함수

# 이미지 시각화
plt.imshow(image) #시각화
plt.title('MOT_Dataset')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.show()
